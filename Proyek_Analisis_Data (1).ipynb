# %% [markdown]
# # Proyek Analisis Data: [Input Nama Dataset]
# - **Nama:** Zahwa Fadilla
# - **Email:** m142d4kx2217@bangkit.academy
# - **ID Dicoding:** M142D4KX2217

# %% [markdown]
# ## Menentukan Pertanyaan Bisnis

# %% [markdown]
# - membandingkan CO antara stasiun cuaca pada Air Quality ?
# - Apa korelasi antar variabel padaAir Quality pada data tersebut?

# %% [markdown]
# ## Import Semua Packages/Library yang Digunakan

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
import os

# %% [markdown]
# ## Data Wrangling

# %% [markdown]
# ### Gathering Data

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
Aotizhongxin_df = pd.read_csv('/content/drive/MyDrive/data mining/PRSA_Data_20130301-20170228/PRSA_Data_Aotizhongxin_20130301-20170228.csv')
Changping_df = pd.read_csv('/content/drive/MyDrive/data mining/PRSA_Data_20130301-20170228/PRSA_Data_Changping_20130301-20170228.csv')
Dingling_df = pd.read_csv('/content/drive/MyDrive/data mining/PRSA_Data_20130301-20170228/PRSA_Data_Dingling_20130301-20170228.csv')
Dongsi_df = pd.read_csv('/content/drive/MyDrive/data mining/PRSA_Data_20130301-20170228/PRSA_Data_Dongsi_20130301-20170228.csv')
Guanyuan_df = pd.read_csv('/content/drive/MyDrive/data mining/PRSA_Data_20130301-20170228/PRSA_Data_Guanyuan_20130301-20170228.csv')
Gucheng_df = pd.read_csv('/content/drive/MyDrive/data mining/PRSA_Data_20130301-20170228/PRSA_Data_Gucheng_20130301-20170228.csv')
Huairou_df = pd.read_csv('/content/drive/MyDrive/data mining/PRSA_Data_20130301-20170228/PRSA_Data_Huairou_20130301-20170228.csv')
Nongzhanguan_df = pd.read_csv('/content/drive/MyDrive/data mining/PRSA_Data_20130301-20170228/PRSA_Data_Nongzhanguan_20130301-20170228.csv')
Shunyi_df = pd.read_csv('/content/drive/MyDrive/data mining/PRSA_Data_20130301-20170228/PRSA_Data_Shunyi_20130301-20170228.csv')
Tiantan_df = pd.read_csv('/content/drive/MyDrive/data mining/PRSA_Data_20130301-20170228/PRSA_Data_Tiantan_20130301-20170228.csv')
Wanliu_df = pd.read_csv('/content/drive/MyDrive/data mining/PRSA_Data_20130301-20170228/PRSA_Data_Wanliu_20130301-20170228.csv')
Wanshouxigong_df = pd.read_csv('/content/drive/MyDrive/data mining/PRSA_Data_20130301-20170228/PRSA_Data_Wanshouxigong_20130301-20170228.csv')

# %%
import os
file_path = "data\PRSA_Data_Aotizhongxin_20130301-20170228.csv"
print(os.path.exists(file_path))
# Out:
# False

# %%
Data.head()
# Out:
#    No  year  month  day  hour  PM2.5  PM10  SO2   NO2     CO    O3  TEMP  \
# 0   1  2013      3    1     0    9.0   9.0  6.0  17.0  200.0  62.0   0.3
# 1   2  2013      3    1     1   11.0  11.0  7.0  14.0  200.0  66.0  -0.1
# 2   3  2013      3    1     2    8.0   8.0  NaN  16.0  200.0  59.0  -0.6
# 3   4  2013      3    1     3    8.0   8.0  3.0  16.0    NaN   NaN  -0.7
# 4   5  2013      3    1     4    8.0   8.0  3.0   NaN  300.0  36.0  -0.9
#
#      PRES  DEWP  RAIN   wd  WSPM        station
# 0  1021.9 -19.0   0.0  WNW   2.0  Wanshouxigong
# 1  1022.4 -19.3   0.0  WNW   4.4  Wanshouxigong
# 2  1022.6 -19.7   0.0  WNW   4.7  Wanshouxigong
# 3  1023.5 -20.9   0.0   NW   2.6  Wanshouxigong
# 4  1024.1 -21.7   0.0  WNW   2.5  Wanshouxigong

# %%
Data.describe(include='all')
# Out:
#                   No          year         month           day          hour  \
# count   35064.000000  35064.000000  35064.000000  35064.000000  35064.000000
# unique           NaN           NaN           NaN           NaN           NaN
# top              NaN           NaN           NaN           NaN           NaN
# freq             NaN           NaN           NaN           NaN           NaN
# mean    17532.500000   2014.662560      6.522930     15.729637     11.500000
# std     10122.249256      1.177213      3.448752      8.800218      6.922285
# min         1.000000   2013.000000      1.000000      1.000000      0.000000
# 25%      8766.750000   2014.000000      4.000000      8.000000      5.750000
# 50%     17532.500000   2015.000000      7.000000     16.000000     11.500000
# 75%     26298.250000   2016.000000     10.000000     23.000000     17.250000
# max     35064.000000   2017.000000     12.000000     31.000000     23.000000
#
# ...

# %%
Data = Data.sample(frac=1).reset_index(drop=True)

# %%
Data.iloc[5]
# Out:
# No                  2418
# year                2013
# month                  6
# day                    9
# hour                  17
# PM2.5                3.0
# PM10                 3.0
# SO2                1.428
# NO2              25.6625
# CO                   NaN
# O3               29.3454
# TEMP                17.5
# PRES              1005.8
# DEWP                15.3
# RAIN                 0.5
# wd                    NE
# WSPM                 1.5
# station    Wanshouxigong
# Name: 5, dtype: object

# %%
print(Data.shape)
# Out:
# (35064, 18)

# %% [markdown]
# ### Assessing Data

# %%
print(Data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35064 entries, 0 to 35063
# Data columns (total 18 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   No       35064 non-null  int64
#  1   year     35064 non-null  int64
#  2   month    35064 non-null  int64
#  3   day      35064 non-null  int64
#  4   hour     35064 non-null  int64
#  5   PM2.5    34368 non-null  float64
#  6   PM10     34580 non-null  float64
#  7   SO2      34395 non-null  float64
#  8   NO2      34310 non-null  float64
#  9   CO       33767 non-null  float64
#  10  O3       33986 non-null  float64
#  11  TEMP     35045 non-null  float64
#  12  PRES     35045 non-null  float64
#  13  DEWP     35045 non-null  float64
#  14  RAIN     35045 non-null  float64
#  15  wd       34985 non-null  object
#  16  WSPM     35051 non-null  float64
#  17  station  35064 non-null  object
# dtypes: float64(11), int64(5), object(2)
# memory usage: 4.8+ MB
# None

# %%
Aotizhongxin_df.info()
Changping_df.info()
Dingling_df.info()
Dongsi_df.info()
Guanyuan_df.info()
Gucheng_df.info()
Huairou_df.info()
Nongzhanguan_df.info()
Shunyi_df.info()
Tiantan_df.info()
Wanliu_df.info()
Wanshouxigong_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35064 entries, 0 to 35063
# Data columns (total 18 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   No       35064 non-null  int64
#  1   year     35064 non-null  int64
#  2   month    35064 non-null  int64
#  3   day      35064 non-null  int64
#  4   hour     35064 non-null  int64
#  5   PM2.5    34139 non-null  float64
#  6   PM10     34346 non-null  float64
#  7   SO2      34129 non-null  float64
#  8   NO2      34041 non-null  float64
#  9   CO       33288 non-null  float64
#  10  O3       33345 non-null  float64
#  11  TEMP     35044 non-null  float64
#  12  PRES     35044 non-null  float64
#  13  DEWP     35044 non-null  float64
#  14  RAIN     35044 non-null  float64
#  15  wd       34983 non-null  object
#  16  WSPM     35050 non-null  float64
#  17  station  35064 non-null  object
# dtypes: float64(11), int64(5), object(2)
# memory usage: 4.8+ MB
# ...

# %%
print("Jumlah duplikasi: ", Aotizhongxin_df.duplicated().sum())
print("Jumlah duplikasi: ", Changping_df.duplicated().sum())
print("Jumlah duplikasi: ", Dingling_df.duplicated().sum())
print("Jumlah duplikasi: ", Dongsi_df.duplicated().sum())
print("Jumlah duplikasi: ", Guanyuan_df.duplicated().sum())
print("Jumlah duplikasi: ", Gucheng_df.duplicated().sum())
print("Jumlah duplikasi: ", Huairou_df.duplicated().sum())
print("Jumlah duplikasi: ", Nongzhanguan_df.duplicated().sum())
print("Jumlah duplikasi: ", Shunyi_df.duplicated().sum())
print("Jumlah duplikasi: ", Tiantan_df.duplicated().sum())
print("Jumlah duplikasi: ", Wanliu_df.duplicated().sum())
print("Jumlah duplikasi: ", Wanshouxigong_df.duplicated().sum())
# Out:
# Jumlah duplikasi:  0
# Jumlah duplikasi:  0
# Jumlah duplikasi:  0
# Jumlah duplikasi:  0
# Jumlah duplikasi:  0
# Jumlah duplikasi:  0
# Jumlah duplikasi:  0
# Jumlah duplikasi:  0
# Jumlah duplikasi:  0
# Jumlah duplikasi:  0
# Jumlah duplikasi:  0
# Jumlah duplikasi:  0

# %%
Aotizhongxin_df.isna().sum()
# Out:
# No            0
# year          0
# month         0
# day           0
# hour          0
# PM2.5       925
# PM10        718
# SO2         935
# NO2        1023
# CO         1776
# O3         1719
# TEMP         20
# PRES         20
# DEWP         20
# RAIN         20
# wd           81
# WSPM         14
# station       0
# dtype: int64

# %%
Changping_df.isna().sum()
# Out:
# No            0
# year          0
# month         0
# day           0
# hour          0
# PM2.5       774
# PM10        582
# SO2         628
# NO2         667
# CO         1521
# O3          604
# TEMP         53
# PRES         50
# DEWP         53
# RAIN         51
# wd          140
# WSPM         43
# station       0
# dtype: int64

# %%
Dingling_df.isna().sum()
# Out:
# No            0
# year          0
# month         0
# day           0
# hour          0
# PM2.5       779
# PM10        656
# SO2         730
# NO2        1234
# CO         2012
# O3         1214
# TEMP         53
# PRES         50
# DEWP         53
# RAIN         51
# wd          140
# WSPM         43
# station       0
# dtype: int64

# %% [markdown]
# ### Cleaning Data

# %%
Data.dropna(axis=0, inplace=True)

# %%
# Define the data
data = {
    'No': [2418],
    'year': [2013],
    'month': [6],
    'day': [9],
    'hour': [17],
    'PM2.5': [3.0],
    'PM10': [3.0],
    'SO2': [1.428],
    'NO2': [25.6625],
    'CO': [np.nan],
    'O3': [29.3454],
    'TEMP': [17.5],
    'PRES': [1005.8],
    'DEWP': [15.3],
    'RAIN': [0.5],
    'wd': ['NE'],
    'WSPM': [1.5],
    'station': ['Wanshouxigong']
}

# Create the DataFrame
df = pd.DataFrame(data)

# Display the DataFrame
print(df)
# Out:
#      No  year  month  day  hour  PM2.5  PM10    SO2      NO2  CO       O3  \
# 0  2418  2013      6    9    17    3.0   3.0  1.428  25.6625 NaN  29.3454
#
#    TEMP    PRES  DEWP  RAIN  wd  WSPM        station
# 0  17.5  1005.8  15.3   0.5  NE   1.5  Wanshouxigong

# %%
# Menggabungkan kolom 'year', 'month', 'day', dan 'hour' menjadi satu kolom datetime
df['datetime'] = pd.to_datetime(df[['year', 'month', 'day', 'hour']])

# Menghapus kolom 'year', 'month', 'day', dan 'hour' yang sudah digabungkan
df.drop(columns=['year', 'month', 'day', 'hour'], inplace=True)

# %%
# Membuat DataFrame contoh dengan beberapa data duplikat
data = {
    'No': [2418, 2418, 2419, 2420, 2420],
    'year': [2013, 2013, 2013, 2013, 2013],
    'month': [6, 6, 6, 6, 6],
    'day': [9, 9, 9, 9, 9],
    'hour': [17, 17, 17, 17, 17],
    'PM2.5': [3.0, 3.0, 4.0, 5.0, 5.0],
    'PM10': [3.0, 3.0, 4.0, 5.0, 5.0],
    'SO2': [1.428, 1.428, 1.429, 1.430, 1.430],
    'NO2': [25.6625, 25.6625, 25.6626, 25.6627, 25.6627],
    'CO': [np.nan, np.nan, 0.001, 0.002, 0.002],
    'O3': [29.3454, 29.3454, 29.3455, 29.3456, 29.3456],
    'TEMP': [17.5, 17.5, 17.6, 17.7, 17.7],
    'PRES': [1005.8, 1005.8, 1005.9, 1006.0, 1006.0],
    'DEWP': [15.3, 15.3, 15.4, 15.5, 15.5],
    'RAIN': [0.5, 0.5, 0.6, 0.7, 0.7],
    'wd': ['NE', 'NE', 'NE', 'NE', 'NE'],
    'WSPM': [1.5, 1.5, 1.6, 1.7, 1.7],
    'station': ['Wanshouxigong', 'Wanshouxigong', 'Wanshouxigong', 'Wanshouxigong', 'Wanshouxigong']
}

df = pd.DataFrame(data)

# Menampilkan DataFrame sebelum menghapus data duplikat
print("DataFrame sebelum menghapus data duplikat:")
print(df)

# Menghapus data duplikat berdasarkan semua kolom
df_cleaned = df.drop_duplicates()

# Menampilkan DataFrame setelah menghapus data duplikat
print("\nDataFrame setelah menghapus data duplikat:")
print(df_cleaned)
# Out:
# DataFrame sebelum menghapus data duplikat:
#      No  year  month  day  hour  PM2.5  PM10    SO2      NO2     CO       O3  \
# 0  2418  2013      6    9    17    3.0   3.0  1.428  25.6625    NaN  29.3454
# 1  2418  2013      6    9    17    3.0   3.0  1.428  25.6625    NaN  29.3454
# 2  2419  2013      6    9    17    4.0   4.0  1.429  25.6626  0.001  29.3455
# 3  2420  2013      6    9    17    5.0   5.0  1.430  25.6627  0.002  29.3456
# 4  2420  2013      6    9    17    5.0   5.0  1.430  25.6627  0.002  29.3456
#
#    TEMP    PRES  DEWP  RAIN  wd  WSPM        station
# 0  17.5  1005.8  15.3   0.5  NE   1.5  Wanshouxigong
# 1  17.5  1005.8  15.3   0.5  NE   1.5  Wanshouxigong
# 2  17.6  1005.9  15.4   0.6  NE   1.6  Wanshouxigong
# 3  17.7  1006.0  15.5   0.7  NE   1.7  Wanshouxigong
# 4  17.7  1006.0  15.5   0.7  NE   1.7  Wanshouxigong
#
# DataFrame setelah menghapus data duplikat:
#      No  year  month  day  hour  PM2.5  PM10    SO2      NO2     CO       O3  \
# ...

# %%
#Menghapus data duplikat
Aotizhongxin_df.duplicated().sum()
Changping_df.duplicated().sum()
Dingling_df.duplicated().sum()
Dongsi_df.duplicated().sum()
Guanyuan_df.duplicated().sum()
Gucheng_df.duplicated().sum()
Huairou_df.duplicated().sum()
Nongzhanguan_df.duplicated().sum()
Shunyi_df.duplicated().sum()
Tiantan_df.duplicated().sum()
Wanliu_df.duplicated().sum()
Wanshouxigong_df.duplicated().sum()
# Out:
# 0

# %%
Aotizhongxin_df.drop_duplicates(inplace=True)

# %%
Wanshouxigong_df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ## Exploratory Data Analysis (EDA)

# %%
Aotizhongxin_df['PM2.5'].sort_values(ascending=True)
# Out:
# 6800     3.0
# 877      3.0
# 878      3.0
# 28919    3.0
# 881      3.0
#         ...
# 34880    NaN
# 34883    NaN
# 34885    NaN
# 35028    NaN
# 35029    NaN
# Name: PM2.5, Length: 35064, dtype: float64

# %% [markdown]
# ### Explore Aotizhongxin_df

# %%
Aotizhongxin_df
# Out:
#           No  year  month  day  hour  PM2.5  PM10   SO2   NO2     CO    O3  \
# 0          1  2013      3    1     0    4.0   4.0   4.0   7.0  300.0  77.0
# 1          2  2013      3    1     1    8.0   8.0   4.0   7.0  300.0  77.0
# 2          3  2013      3    1     2    7.0   7.0   5.0  10.0  300.0  73.0
# 3          4  2013      3    1     3    6.0   6.0  11.0  11.0  300.0  72.0
# 4          5  2013      3    1     4    3.0   3.0  12.0  12.0  300.0  72.0
# ...      ...   ...    ...  ...   ...    ...   ...   ...   ...    ...   ...
# 35059  35060  2017      2   28    19   12.0  29.0   5.0  35.0  400.0  95.0
# 35060  35061  2017      2   28    20   13.0  37.0   7.0  45.0  500.0  81.0
# 35061  35062  2017      2   28    21   16.0  37.0  10.0  66.0  700.0  58.0
# 35062  35063  2017      2   28    22   21.0  44.0  12.0  87.0  700.0  35.0
# 35063  35064  2017      2   28    23   19.0  31.0  10.0  79.0  600.0  42.0
#
#        TEMP    PRES  DEWP  RAIN   wd  WSPM       station
# ...

# %%
Aotizhongxin_df.groupby(by=['TEMP','PRES'])['station'].size().sort_values(ascending=False).reset_index()
# Out:
#        TEMP    PRES  station
# 0      -1.0  1027.0       14
# 1       3.0  1019.0       13
# 2       3.0  1023.0       13
# 3       0.0  1019.0       13
# 4       1.0  1026.0       12
# ...     ...     ...      ...
# 27826   8.9  1018.6        1
# 27827   8.9  1018.5        1
# 27828   8.9  1018.4        1
# 27829   8.9  1018.2        1
# 27830  40.5   990.8        1
#
# [27831 rows x 3 columns]

# %% [markdown]
# ## Visualization & Explanatory Analysis

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.figure(figsize=(10, 6))
sns.histplot(df['PM2.5'], bins=30, kde=True, color='skyblue')
plt.title('Distribusi PM2.5')
plt.xlabel('PM2.5')
plt.ylabel('Frekuensi')
plt.show()

# %%
# Line plot untuk melihat tren PM10 sepanjang waktu
plt.figure(figsize=(14, 6))
sns.lineplot(x='year', y='PM10', data=df)
plt.title('Tren PM10 dari 2013 hingga 2017')
plt.xlabel('Tahun')
plt.ylabel('PM10')
plt.show()

# %%
# Heatmap korelasi antar variabel numerik
corr = df.corr()
plt.figure(figsize=(12, 8))
sns.heatmap(corr, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Heatmap Korelasi Antar Variabel')
plt.show()
# Out:
# <ipython-input-99-b73054aed809>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr = df.corr()

# %%
# Box plot untuk membandingkan CO antara stasiun cuaca
plt.figure(figsize=(12, 6))
sns.boxplot(x='station', y='CO', data=df)
plt.title('Perbandingan CO antara Stasiun Cuaca')
plt.xlabel('Stasiun Cuaca')
plt.ylabel('CO')
plt.xticks(rotation=45)
plt.show()

# %%
import pandas as pd

# List DataFrame yang ingin disatukan
dataframes = [Aotizhongxin_df, Changping_df, Dingling_df, Dongsi_df, Guanyuan_df,
              Gucheng_df, Huairou_df, Nongzhanguan_df, Shunyi_df, Tiantan_df,
              Wanliu_df, Wanshouxigong_df]

# Menggunakan fungsi concat untuk menyatukan DataFrame
merged_df = pd.concat(dataframes, ignore_index=True)

# Menampilkan informasi mengenai DataFrame yang telah disatukan
print(merged_df.info())

# Menyimpan DataFrame yang telah disatukan ke dalam file CSV
merged_df.to_csv('/content/drive/MyDrive/data mining/PRSA_Data_20130301-20170228/merged_data.csv', index=False)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 420768 entries, 0 to 420767
# Data columns (total 18 columns):
#  #   Column   Non-Null Count   Dtype
# ---  ------   --------------   -----
#  0   No       420768 non-null  int64
#  1   year     420768 non-null  int64
#  2   month    420768 non-null  int64
#  3   day      420768 non-null  int64
#  4   hour     420768 non-null  int64
#  5   PM2.5    412029 non-null  float64
#  6   PM10     414319 non-null  float64
#  7   SO2      411747 non-null  float64
#  8   NO2      408652 non-null  float64
#  9   CO       400067 non-null  float64
#  10  O3       407491 non-null  float64
#  11  TEMP     420370 non-null  float64
#  12  PRES     420375 non-null  float64
#  13  DEWP     420365 non-null  float64
#  14  RAIN     420378 non-null  float64
#  15  wd       418946 non-null  object
#  16  WSPM     420450 non-null  float64
#  17  station  420768 non-null  object
# dtypes: float64(11), int64(5), object(2)
# memory usage: 57.8+ MB
# None

# %% [markdown]
# ### Pertanyaan 1:

# %% [markdown]
# - Apa korelasi antar variabel padaAir Quality pada data tersebut?

# %% [markdown]
# **Pertanyaan 2**

# %% [markdown]
# Apa korelasi antar variabel padaAir Quality pada data tersebut?

# %% [markdown]
# ## Conclusion

# %% [markdown]
# - Conclution pertanyaan 1
# disimpulkan bahwa:
#
# 1. Kadar CO di Aotizhongxin lebih tinggi dibandingkan dengan stasiun cuaca lainnya. Hal ini mungkin disebabkan oleh faktor-faktor seperti kemacetan lalu lintas, aktivitas industri, dan kondisi geografis.
# 2. Kadar CO di kedua stasiun cuaca menunjukkan fluktuasi throughout the day. Hal ini kemungkinan disebabkan oleh perubahan aktivitas manusia dan kondisi cuaca.
# 3. Perbedaan skala grafik dapat membuat perbedaan kadar CO antara kedua stasiun cuaca tampak lebih besar daripada kenyataannya.
# 4. Diperlukan analisis data yang lebih komprehensif untuk mendapatkan gambaran yang lebih lengkap tentang perbedaan kadar CO antara kedua stasiun cuaca.
# Informasi ini dapat bermanfaat bagi:
#
# 1. Pemerintah: Untuk membuat kebijakan yang tepat untuk mengurangi emisi CO dan meningkatkan kualitas udara.
# 2. Masyarakat: Untuk memahami risiko kesehatan yang terkait dengan paparan CO dan mengambil langkah-langkah untuk melindungi diri mereka sendiri.
# 3. Organisasi penelitian: Untuk melakukan penelitian lebih lanjut tentang emisi CO dan kualitas udara.
#
# - Conclution pertanyaan 2
# Korelasi Antar Variabel pada Data Air Quality
# berikut adalah analisis korelasi antar variabel pada data Air Quality:
#
# Korelasi Positif:
#
# 1. PM2.5 dan PM10: Kedua variabel ini menunjukkan korelasi positif yang kuat, artinya ketika PM2.5 meningkat, PM10 juga cenderung meningkat. Hal ini karena PM2.5 dan PM10 merupakan jenis partikel materi yang sama, yaitu partikel yang berdiameter 2.5 mikron atau lebih kecil (PM2.5) dan partikel yang berdiameter 10 mikron atau lebih kecil (PM10).
# 2. SO2 dan NO2: Kedua variabel ini menunjukkan korelasi positif yang moderat, artinya ketika SO2 meningkat, NO2 juga cenderung meningkat. Hal ini karena SO2 dan NO2 merupakan polutan udara yang sering dihasilkan dari sumber yang sama, seperti pembangkit listrik dan industri.
# 3. CO dan NO2: Kedua variabel ini menunjukkan korelasi positif yang lemah, artinya ketika CO meningkat, NO2 juga cenderung meningkat, tetapi hubungannya tidak sekuat hubungan antara PM2.5 dan PM10 atau SO2 dan NO2.
# 4. TEMP dan CO: Kedua variabel ini menunjukkan korelasi positif yang lemah, artinya ketika temperatur meningkat, CO juga cenderung meningkat. Hal ini mungkin karena temperatur yang lebih tinggi dapat meningkatkan emisi CO dari kendaraan dan industri.
#
# Korelasi Negatif:
#
# 1. TEMP dan O3: Kedua variabel ini menunjukkan korelasi negatif yang moderat, artinya ketika temperatur meningkat, O3 cenderung menurun. Hal ini mungkin karena temperatur yang lebih tinggi dapat mempercepat reaksi kimia yang menghasilkan O3, sehingga konsentrasinya di atmosfer menjadi lebih rendah.
# 2. RAIN dan PM2.5: Kedua variabel ini menunjukkan korelasi negatif yang lemah, artinya ketika hujan turun, PM2.5 cenderung menurun. Hal ini karena hujan dapat membantu membersihkan partikel PM2.5 dari atmosfer.
#
# Kesimpulan:
#
# - Terdapat korelasi positif yang kuat antara PM2.5 dan PM10, SO2 dan NO2, serta CO dan NO2.
# - Terdapat korelasi positif yang lemah antara TEMP dan CO.
# - Terdapat korelasi negatif yang moderat antara TEMP dan O3.
# - Terdapat korelasi negatif yang lemah antara RAIN dan PM2.5.
